# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
base = pd.read_excel("C:/Users/Ronalde/Dados.xlsx")

# %%
type(base)
# Out:
# pandas.core.frame.DataFrame

# %%
base.head()
# Out:
#         Data  Vendas
# 0 2022-12-06     870
# 1 2022-12-07     868
# 2 2022-12-08    1189
# 3 2022-12-09     742
# 4 2022-12-10     317

# %%
base.groupby(['Data']).size().head()
# Out:
# Data
# 2022-12-06    1
# 2022-12-07    1
# 2022-12-08    1
# 2022-12-09    1
# 2022-12-10    1
# dtype: int64

# %%
plt.figure(figsize=(10, 8))
base.Vendas.hist(bins = 20)
plt.xlabel("Quantidade de vendas")
plt.ylabel("Quantidade")
plt.title("Acompanhamento das Vendas", color='red')
plt.show()

# %%
from sklearn import linear_model
regre = linear_model.LinearRegression()

# %%
Xv = base.iloc[:,0].values
y = base['Vendas'].values

# %%
ANO = base['Data'].dt.year.values

# %%
Xm = np.array([Xv])
X = Xm.T

# %%
regre.fit(X,y)
# Out:
# LinearRegression()

# %%
plt.figure(figsize=(17, 6))
plt.scatter(X,y,color='red')
plt.plot(X,y, color = 'blue', linewidth=2)
plt.show()

# %%
plt.figure(figsize=(17, 6))
plt.scatter(ANO,y,color='red')
plt.plot(ANO,y, color = 'blue', linewidth=2)
plt.show()

# %%
plt.scatter(ANO,y,label='y(x)');
plt.xlabel('ANO');
plt.ylabel('y');
plt.legend();
