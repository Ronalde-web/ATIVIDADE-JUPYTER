# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import numpy as np

# %matplotlib inline
rcParams['figure.figsize'] = 15,6
sns.set_style('whitegrid')

# %%
path = 'C:/Users/Ronalde/campoes_brasileiro.csv'

dados = pd.read_csv(path)
dados
# Out:
#      Ano     Vencedor              Vice Terceiro colocado   Quarto colocado  \
# 0   1959        Bahia            Santos            Grêmio     Vasco da Gama
# 1   1960    Palmeiras         Fortaleza        Fluminense        Santa Cruz
# 2   1961       Santos             Bahia           America           Náutico
# 3   1962       Santos          Botafogo     Internacional             Sport
# 4   1963       Santos             Bahia            Grêmio          Botafogo
# ..   ...          ...               ...               ...               ...
# 58  2015  Corinthians  Atlético Mineiro            Grêmio         São Paulo
# 59  2016    Palmeiras            Santos          Flamengo  Atlético Mineiro
# 60  2017  Corinthians         Palmeiras            Santos            Grêmio
# 61  2018    Palmeiras          Flamengo     Internacional            Grêmio
# 62  2019     Flamengo            Santos         Palmeiras            Grêmio
#
# ...

# %%
dadosAno = dados['Ano']
dadosVen = dados['Vencedor']

a = dadosAno
b = dadosVen

# %%
plt.xlabel('Ano das Vitorias') # xlabel = criando o nome do eixo x.
plt.ylabel('Times que foram capião') # ylabel = criando o nome do eixo y.



plt.bar(a,b, color='red')
plt.savefig('MeuGrafico.png')
! dir
# Out:
#  O volume na unidade C não tem nome.
#  O Número de Série do Volume é 2877-60A4
#
#  Pasta de C:\Users\Ronalde
#
# 03/12/2021  16:13    <DIR>          .
# 03/12/2021  16:13    <DIR>          ..
# 28/09/2021  10:57    <DIR>          .anaconda
# 05/10/2021  20:38    <DIR>          .astropy
# 17/05/2021  09:59    <DIR>          .cache
# 03/12/2021  16:13    <DIR>          .conda
# 28/09/2021  10:46                42 .condarc
# 17/05/2021  12:10    <DIR>          .continuum
# 17/10/2021  00:31               215 .gitconfig
# 03/12/2021  13:19    <DIR>          .ipynb_checkpoints
# 27/08/2021  10:55    <DIR>          .ipython
# 23/10/2021  12:15    <DIR>          .jupyter
# 27/11/2021  16:58    <DIR>          .kettle
# 31/08/2021  21:20    <DIR>          .matplotlib
# 18/11/2021  17:30    <DIR>          .pentaho
# 18/05/2021  00:33    <DIR>          .portugol
# 18/11/2021  17:27    <DIR>          .swt
# 24/06/2021  21:09    <DIR>          .vscode
# ...

# %%
filtro = dados['Ano'] > 1999
filtroA = dados[filtro]

dado = filtroA["Ano"]
dadob = filtroA["Vencedor"]

r = dado
k = dadob

plt.subplot(1,2,1)
plt.title('Anos que os Times Foram Campeões', color='blue')
plt.bar(r,k, color='red')


# SEGUNDO GRAFICO

dadosA = dados["Artilheiro(s)"]
dadosG = dados["Gols"]


filtro = dados['Ano'] > 2014
novodado = dados[filtro]

dadosA = novodado["Artilheiro(s)"]
dadosG = novodado["Gols"]

c = dadosA
d = dadosG

plt.xlabel('Anos')
plt.ylabel('Times Campeões')
plt.subplot(2,2,2)
plt.bar(c,d)
plt.title('Jogadores Artilheiros', color='red',)
plt.xlabel('Nome dos Jogadores do Ano 2014 á 2019')
plt.ylabel('Quantidade de Gols')
# Out:
# Text(0, 0.5, 'Quantidade de Gols')

# %%
filtro = dados['Vencedor'] =='Vasco'
novodado = dados[filtro]

dadosA = novodado["Artilheiro(s)"]
dadosG = novodado["Gols"]



c = dadosA
d = dadosG

plt.xlabel('Nomes dos Jogadores Artilheiros dos anos (1974-1988-1997-2000)', color='red') # xlabel = criando o nome do eixo x.
plt.ylabel('Quantidades de Gols', color='red') # ylabel = criando o nome do eixo y.

plt.bar(c,d)
# Out:
# <BarContainer object of 4 artists>
